# %% [markdown]
# # Подготовка выборки вопросов для датасета

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/prepared/moscow.csv")
qdf = pd.read_csv("../data/rag/generated_questions.csv")
qdf
# Out:
#                                              question  \
# 0   Какие места в Москве относятся к категории «Ар...
# 1   Что интересного можно найти по адресу: Москва,...
# 2   Найди заведения в Москве с рейтингом 5 и рубри...
# 3           Какие заведения в Москве имеют рейтинг 5?
# 4   Найди заведения в Москве с рейтингом 5 и рубри...
# 5   Найди заведения в Москве с рейтингом 5 и рубри...
# 6   Где в Москве в отзывах упоминается «вкусный ко...
# 7   Где в Москве в отзывах упоминается «вкусный ко...
# 8   Где в Москве в отзывах упоминается «онлайн-сер...
# 9     Где в Москве в отзывах упоминается «атмосфера»?
# 10  Где в Москве в отзывах упоминается «онлайн-сер...
# 11  Какие места в Москве относятся к категории «АЗС»?
# 12  Найди заведения в Москве с рейтингом 5 и рубри...
# 13  Где в Москве в отзывах упоминается «онлайн-сер...
# 14          Какие заведения в Москве имеют рейтинг 5?
# 15  Какие места в Москве относятся к категории «Ст...
# ...

# %%
qdf.question.to_list()
# Out:
# ['Какие места в Москве относятся к категории «Аренда теплоходов»?',
#  'Что интересного можно найти по адресу: Москва, Анадырский проезд, 10?',
#  'Найди заведения в Москве с рейтингом 5 и рубрикой «Кожаные изделия оптом».',
#  'Какие заведения в Москве имеют рейтинг 5?',
#  'Найди заведения в Москве с рейтингом 5 и рубрикой «Изготовление и оптовая продажа сувениров».',
#  'Найди заведения в Москве с рейтингом 5 и рубрикой «Студия пилатеса».',
#  'Где в Москве в отзывах упоминается «вкусный кофе»?',
#  'Где в Москве в отзывах упоминается «вкусный кофе»?',
#  'Где в Москве в отзывах упоминается «онлайн-сервис»?',
#  'Где в Москве в отзывах упоминается «атмосфера»?',
#  'Где в Москве в отзывах упоминается «онлайн-сервис»?',
#  'Какие места в Москве относятся к категории «АЗС»?',
#  'Найди заведения в Москве с рейтингом 5 и рубрикой «Металлообработка».',
#  'Где в Москве в отзывах упоминается «онлайн-сервис»?',
#  'Какие заведения в Москве имеют рейтинг 5?',
# ...
